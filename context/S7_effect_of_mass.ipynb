# %% [markdown]
# # S7 Effect of Mass
#
# 3C6 Section 7: What is the effect of adding mass to a transfer function?
#
# ## imports and definitions

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pydvma as dvma

# %%
# %matplotlib widget

# %% [markdown]
# ## log data

# %%
settings = dvma.MySettings(fs=44100,
                           stored_time=5,
                           viewed_time=2,
                           channels=1,
                           chunk_size=1000,
                           pretrig_samples=200,
                           device_driver='soundcard')

# %%
osc = dvma.Oscilloscope(settings)
# Out:
# 2024-11-22 09:38:42.782 python[18503:713059] +[IMKClient subclass]: chose IMKClient_Modern
# 2024-11-22 09:38:42.782 python[18503:713059] +[IMKInputSession subclass]: chose IMKInputSession_Modern

# %%
logger = dvma.Logger(settings)
# Out:
# Waiting for trigger on channel 0.
#
#
# Waiting for trigger on channel 0.
# Trigger detected. Logging data for 5.0 seconds.
#
# Logging complete.
#
# Waiting for trigger on channel 0.
#
#
# Waiting for trigger on channel 0.
# Trigger detected. Logging data for 5.0 seconds.
#
# Logging complete.
