# %%
import matplotlib
import matplotlib.pyplot as plt
import pydvma as dvma
matplotlib.rcParams.update({'font.size': 12,'font.family':'serif'})

# %%
# %matplotlib widget

# %%
dvma.get_devices_soundcard()
# Out:
# ['DELL P2715Q',
#  'TB phone Microphone',
#  'BlackHole 2ch',
#  'MacBook Pro Microphone',
#  'MacBook Pro Speakers',
#  'Tore',
#  'Microsoft Teams Audio']

# %%
settings = dvma.MySettings(fs=44100,channels=1,stored_time=5,pretrig_samples=100,device_driver='soundcard',device_index=3)

# %%
logger = dvma.Logger(settings,test_name='ABH beam')

# %%
d = logger.dataset
td = d.time_data_list[0]
td.

# %%
logger = dvma.Logger()
# Out:
# 2024-11-21 18:53:39.131 python[14648:588995] +[IMKClient subclass]: chose IMKClient_Modern
# 2024-11-21 18:53:39.131 python[14648:588995] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# 2024-11-21 18:53:42.159 python[14648:588995] The class 'NSOpenPanel' overrides the method identifier.  This method is implemented by class 'NSWindow'
# fn=314.80 (Hz), zn=0.00314, Qn = 1/(2 zn) = 159.4
#
# an=[-14.61]
#
# pn=[21.34] deg

# %%
logger.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 logger.show()
#
# NameError: name 'logger' is not defined

# %%
m = d.modal_data_list[0]
fn = m.fn
Q = 1/2/m.zn

# %%
plt.plot(fn,Q)
plt.xlabel('f_n (Hz)')
plt.ylabel('Q')

# %%
dvma.export_to_csv(d,'ABH_beam.csv')
