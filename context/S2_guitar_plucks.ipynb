# %% [markdown]
# # S2 Guitar pluck
#
# 3C6 Section 2: What is the effect of plucking position on the sound of a guitar?
#
# ## imports and definitions

# %%
# %gui qt

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.animation as animation
matplotlib.rcParams.update({'font.size': 12,'font.family':'serif'})
from ipywidgets import interact

import sounddevice as sd
import pydvma as dvma
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/sounddevice-0.5.2-py3.13.egg/sounddevice.py:71
#      70 else:
# ---> 71     raise OSError('PortAudio library not found')
#      72 _lib = _ffi.dlopen(_libname)
#
# OSError: PortAudio library not found
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 8
#       5 matplotlib.rcParams.update({'font.size': 12,'font.family':'serif'})
#       6 from ipywidgets import interact
# ----> 8 import sounddevice as sd
#       9 import pydvma as dvma
#
# File /opt/anaconda3/lib/python3.13/site-packages/sounddevice-0.5.2-py3.13.egg/sounddevice.py:83
#      81 else:
#      82     raise
# ---> 83 import _sounddevice_data
#      84 _libname = _os.path.join(
#      85     next(iter(_sounddevice_data.__path__)), 'portaudio-binaries', _libname)
#      86 _lib = _ffi.dlopen(_libname)
#
# ModuleNotFoundError: No module named '_sounddevice_data'

# %%
matplotlib.use('nbagg')

# %% [markdown]
# ## Log data

# %%
settings = dvma.MySettings(fs=8000,
                           stored_time=2,
                           viewed_time=2,
                           channels=1,
                           device_index=1,
                           chunk_size=100,
                           pretrig_samples=50)

# %%
osc = dvma.Oscilloscope(settings)

# %%
logger = dvma.Logger(settings)
